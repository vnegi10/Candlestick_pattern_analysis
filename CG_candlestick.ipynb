# %% [markdown]
# ### Imports

# %%
import pandas as pd

import requests as rq
import json
from datetime import datetime
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ### Keys

# %%
# Get demo API key
def get_demo_key():
    f = open("/home/vikas/Documents/CG_demo_key.json")
    key_dict = json.load(f)
    return key_dict["key"]

# %%
# Get pro API key
def get_pro_key():
    f = open("/home/vikas/Documents/CG_pro_key.json")
    key_dict = json.load(f)
    return key_dict["key"]

# %% [markdown]
# ### API status

# %%
PUB_URL = "https://api.coingecko.com/api/v3"
PRO_URL = "https://pro-api.coingecko.com/api/v3"

# %%
def get_response(endpoint, headers, params, URL):
    
    url = "".join((URL, endpoint))
    response = rq.get(url, headers = headers, params = params)
    
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print(f"Failed to fetch data, check status code {response.status_code}")

# %%
use_demo = {
           "accept": "application/json",
           "x-cg-demo-api-key" : get_demo_key() 
}

use_pro = {
         "accept": "application/json",
         "x-cg-pro-api-key" : get_pro_key()
}

# %%
get_response("/ping", use_demo, "", PUB_URL)
# Out:
# {'gecko_says': '(V3) To the Moon!'}

# %% [markdown]
# #### List of coins

# %%
def get_list_of_coins():

    response = get_response("/coins/list", use_demo, "", PUB_URL)

    return pd.DataFrame(response)

# %%
df_coins = get_list_of_coins()

df_coins[df_coins["symbol"] == "btc"]
# Out:
#                      id symbol              name
# 1836             batcat    btc            batcat
# 2079       big-tom-coin    btc      Big Tom Coin
# 2195            bitcoin    btc           Bitcoin
# 2203       bitcoin-ai-2    btc        Bitcoin AI
# 2531      bobby-the-cat    btc     Bobby The Cat
# 2532    bobby-the-cat-2    btc     Bobby The Cat
# 10433  mezo-wrapped-btc    btc  Mezo Wrapped BTC
# 12019    osmosis-allbtc    btc    Osmosis allBTC

# %% [markdown]
# ### OHLC

# %%
def get_ohlc_data(coin_id,
                  target_curr,
                  days,
                  precision,
                  interval = "daily"):
    
    ohlc_params = {
        "vs_currency": target_curr,
        "days": days,
        "precision": precision,
        "interval": interval
    }

    ohlc_list_response = get_response(f"/coins/{coin_id}/ohlc",
                                      use_pro,
                                      ohlc_params,
                                      PRO_URL)

    # Convert to DataFrame and assign column names
    df_ohlc = pd.DataFrame(ohlc_list_response,
                           columns=["timestamp", "open", "high", "low", "close"])

    # Convert timestamp from milliseconds to datetime
    df_ohlc["timestamp"] = pd.to_datetime(df_ohlc["timestamp"], unit='ms')

    return df_ohlc

# %%
get_ohlc_data("bitcoin", "usd", 90, "2", "daily")
# Out:
#     timestamp       open       high        low      close
# 89 2025-09-27  109233.05  110310.96  108775.84  109710.21
# 88 2025-09-26  113317.16  113492.31  108787.16  108963.53
# 87 2025-09-25  112002.46  113940.92  111368.80  113320.57
# 86 2025-09-24  112692.50  113300.64  111581.62  112022.17
# 85 2025-09-23  115255.85  115393.87  112103.38  112696.74
# ..        ...        ...        ...        ...        ...
# 4  2025-07-04  108876.33  110386.20  108625.12  109602.20
# 3  2025-07-03  105671.38  109608.34  105401.79  108824.44
# 2  2025-07-02  107135.63  107498.95  105403.45  105613.40
# 1  2025-07-01  108387.33  108771.41  106830.95  107132.80
# 0  2025-06-30  107332.78  108448.63  107228.23  108396.62
#
# [90 rows x 5 columns]

# %% [markdown]
# #### Plot candlestick

# %%
def plot_candlestick(coin_id,
                     target_curr,
                     days,
                     precision,
                     ):

    df_ohlc = get_ohlc_data(coin_id, 
                            target_curr,
                            days,
                            precision)

    target_curr = target_curr.upper()
    
    fig = go.Figure(
        data=[
            go.Candlestick(
                x = df_ohlc["timestamp"],
                open = df_ohlc["open"],
                high = df_ohlc["high"],
                low  = df_ohlc["low"],
                close = df_ohlc["close"],
                name = f"Price [{target_curr}]",
            )
        ]
    )

    fig.update_layout(
        title={
        'text': f'Candlestick chart for {coin_id} over {days} days',
        'x': 0.5,
        'xanchor': 'center'
        },
        xaxis_title = "Date",
        yaxis_title = f"Price [{target_curr}]",
        xaxis_rangeslider_visible = False,
        # Optional: use "plotly", "ggplot2", "seaborn", etc.
        template = "plotly",
        height = 600
    )

    fig.show()

    return None

# %%
plot_candlestick("bitcoin", "usd", 90, "2")

# %% [markdown]
# #### SMA

# %%
def add_sma(df_ohlc, window_short, window_long):

    df_ohlc['sma_short'] = df_ohlc['close'].rolling(window = window_short).mean()
    df_ohlc['sma_long'] = df_ohlc['close'].rolling(window = window_long).mean()

    return df_ohlc

# %% [markdown]
# #### Plot candlestick + SMA

# %%
def plot_candlestick_sma(coin_id,
                         target_curr,
                         days,
                         precision,
                         window_short,
                         window_long
                         ):

    df_ohlc = get_ohlc_data(coin_id, 
                            target_curr,
                            days,
                            precision)
    
    df_ohlc = add_sma(df_ohlc, window_short, window_long)

    target_curr = target_curr.upper()   

    fig = go.Figure()
    
    # Candlestick trace
    fig.add_trace(go.Candlestick(
        x = df_ohlc['timestamp'],
        open = df_ohlc['open'],
        high = df_ohlc['high'],
        low = df_ohlc['low'],
        close = df_ohlc['close'],
        name = 'OHLC'
    ))

    # SMA short window
    fig.add_trace(go.Scatter(
        x = df_ohlc['timestamp'],
        y = df_ohlc['sma_short'],
        mode = 'lines',
        line = dict(color = 'blue', width = 1),
        name = f"SMA {window_short}"
    ))

    # SMA 200 trace
    fig.add_trace(go.Scatter(
        x = df_ohlc['timestamp'],
        y = df_ohlc['sma_long'],
        mode = 'lines',
        line = dict(color = 'orange', width = 1),
        name = f"SMA {window_long}"
    ))

    # Update layout
    fig.update_layout(
        title=dict(
            text = f"Candlestick chart with SMA {window_short} & SMA {window_long}",
            x = 0.5,  # Center title
            xanchor = 'center'
        ),
        xaxis_title = 'Date',
        yaxis_title = f'Price [{target_curr}]',
        xaxis_rangeslider_visible = False,
        template = "plotly",
        height = 600
    )

    fig.show()

    return None

# %%
plot_candlestick_sma("bitcoin", "usd", 180, "2", 10, 30)

# %% [markdown]
# #### RSI

# %%
def add_rsi(df,
            period = 14,
            column = 'close'):
    
    delta = df[column].diff()

    # Positive gains (up) and losses (down)
    gain = delta.where(delta > 0, 0.0)
    loss = -delta.where(delta < 0, 0.0)

    # Use exponential moving average (EMA) for smoothing
    avg_gain = gain.rolling(window=period, min_periods=period).mean()
    avg_loss = loss.rolling(window=period, min_periods=period).mean()

    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))

    df['rsi'] = rsi
    return df

# %%
#add_rsi(get_ohlc_data("bitcoin", "usd", "365", "2"))

# %% [markdown]
# #### Plot candlestick + RSI

# %%
def plot_candlestick_rsi(coin_id,
                         target_curr,
                         days,
                         precision,
                         ):

    df_ohlc = get_ohlc_data(coin_id, 
                            target_curr,
                            days,
                            precision)
    
    df_ohlc = add_rsi(df_ohlc)

    target_curr = target_curr.upper()

    # Create subplot with 2 rows: candlestick and RSI
    fig = make_subplots(
        rows = 2,
        cols = 1,
        shared_xaxes = True,
        shared_yaxes = False,        
        row_heights = [0.5, 0.5],
        vertical_spacing = 0.2,
        subplot_titles = ("Candlestick chart",
                          "Relative Strength Index (RSI)")
    )
    
    fig.add_trace(
        go.Candlestick(
            x=df_ohlc['timestamp'],
            open=df_ohlc['open'],
            high=df_ohlc['high'],
            low=df_ohlc['low'],
            close=df_ohlc['close'],
            name='OHLC'
        ),
        row=1, col=1
    )

    fig.add_trace(
        go.Scatter(
            x=df_ohlc['timestamp'],
            y=df_ohlc['rsi'],
            mode='lines',
            line=dict(color='green'),
            name='RSI'
        ),
        row=2, col=1
    )

    # Add overbought/oversold RSI lines (70/30)
    fig.add_hline(y = 70, line = dict(color = "red", dash = "dash"), row = 2, col = 1)
    fig.add_hline(y = 30, line = dict(color = "blue", dash = "dash"), row = 2, col = 1)

    # Layout settings
    fig.update_layout(
        title={
            'text': f'Candlestick and RSI chart for {coin_id} over {days} days',
            'x': 0.5,
            'xanchor': 'center'
        },
        #xaxis_title = 'Date',
        yaxis_title = f"Price [{target_curr}]",
        yaxis2_title = 'RSI',
        height = 1000,
        template = "plotly"
    )

    fig.show()

    return None

# %%
plot_candlestick_rsi("bitcoin", "usd", "180", "2")

# %% [markdown]
# #### Bollinger bands

# %%
def add_bollinger_bands(df,
                        window = 14,
                        column = 'close'):

    df['middle_band'] = df[column].rolling(window=window).mean()
    df['std_dev'] = df[column].rolling(window=window).std()
    df['upper_band'] = df['middle_band'] + (2 * df['std_dev'])
    df['lower_band'] = df['middle_band'] - (2 * df['std_dev'])
    
    return df

# %% [markdown]
# #### Plot candlestick + Bollinger bands

# %%
def plot_candlestick_boll_bands(coin_id,
                                target_curr,
                                days,
                                precision,
                               ):

    df_ohlc = get_ohlc_data(coin_id, 
                            target_curr,
                            days,
                            precision)
    
    df_ohlc = add_bollinger_bands(df_ohlc)

    target_curr = target_curr.upper()
    
    fig = go.Figure()
    
    fig.add_trace(
        go.Candlestick(
            x=df_ohlc['timestamp'],
            open=df_ohlc['open'],
            high=df_ohlc['high'],
            low=df_ohlc['low'],
            close=df_ohlc['close'],
            name='OHLC'
        )        
    )

    # Add Bollinger Bands
    # Upper Band - Dark Red
    fig.add_trace(go.Scatter(
        x=df_ohlc['timestamp'],
        y=df_ohlc['upper_band'],
        line=dict(color='firebrick', width=1.5),
        name='Upper Band'
    ))

    # Middle Band - Dark Blue
    fig.add_trace(go.Scatter(
        x=df_ohlc['timestamp'],
        y=df_ohlc['middle_band'],
        line=dict(color='darkblue', width=1.5, dash='dot'),
        name='Middle Band'
    ))

    # Lower Band - Dark Green
    fig.add_trace(go.Scatter(
        x=df_ohlc['timestamp'],
        y=df_ohlc['lower_band'],
        line=dict(color='darkgreen', width=1.5),
        name='Lower Band'
    ))

    # Layout settings
    fig.update_layout(
        title={
            'text': f'Candlestick and Bollinger bands for {coin_id} over {days} days',
            'x': 0.5,
            'xanchor': 'center'
        },
        xaxis_title = 'Date',
        yaxis_title = f"Price [{target_curr}]",
        xaxis_rangeslider_visible = False,
        template = "plotly",
        height = 600
    )

    fig.show()

    return None

# %%
plot_candlestick_boll_bands("bitcoin", "usd", "180", "2")

# %% [markdown]
# #### MACD

# %%
def add_macd(df,
             short_window=12,
             long_window=26,
             signal_window=9):
        
    df['ema_short'] = df['close'].ewm(span=short_window, adjust=False).mean()
    df['ema_long'] = df['close'].ewm(span=long_window, adjust=False).mean()
    
    # MACD = short EMA - long EMA
    df['macd'] = df['ema_short'] - df['ema_long']
    
    # Signal line = 9-period EMA of MACD
    df['macd_signal'] = df['macd'].ewm(span=signal_window, adjust=False).mean()

    # Calculate MACD histogram
    df['macd_histogram'] = df['macd'] - df['macd_signal']
    
    df.drop(columns=['ema_short', 'ema_long'], inplace=True)

    return df

# %% [markdown]
# #### Plot candlestick + RSI + MACD

# %%
def plot_candlestick_rsi_macd(coin_id,
                              target_curr,
                              days,
                              precision,
                             ):

    df_ohlc = get_ohlc_data(coin_id, 
                            target_curr,
                            days,
                            precision)
    
    df_ohlc = add_rsi(df_ohlc)

    df_ohlc = add_macd(df_ohlc)

    target_curr = target_curr.upper()

    # Create 3-row figure
    fig = make_subplots(
        rows=3, cols=1,
        shared_xaxes = True,
        shared_yaxes = False,
        row_heights=[0.5, 0.5, 0.5],
        vertical_spacing=0.2,
        subplot_titles=("Candlestick Chart", "RSI", "MACD")
    )

    # === Row 1: Candlestick ===
    fig.add_trace(
        go.Candlestick(
            x=df_ohlc['timestamp'],
            open=df_ohlc['open'],
            high=df_ohlc['high'],
            low=df_ohlc['low'],
            close=df_ohlc['close'],
            name='OHLC'
        ),
        row=1, col=1
    )

    # === Row 2: RSI ===
    fig.add_trace(
        go.Scatter(
            x=df_ohlc['timestamp'],
            y=df_ohlc['rsi'],
            mode='lines',
            line=dict(color='green'),
            name='RSI'
        ),
        row=2, col=1
    )

    # Add overbought/oversold RSI lines (70/30)
    fig.add_hline(y = 70, line = dict(color = "red", dash = "dash"), row = 2, col = 1)
    fig.add_hline(y = 30, line = dict(color = "blue", dash = "dash"), row = 2, col = 1)

    # === Row 3: MACD ===
    fig.add_trace(go.Scatter(x=df_ohlc['timestamp'],
                             y=df_ohlc['macd'],
                             mode='lines',
                             name='MACD',
                             line=dict(color='teal')
                            ),
                            row=3, col=1)
    
    fig.add_trace(go.Scatter(x=df_ohlc['timestamp'],
                             y=df_ohlc['macd_signal'],
                             mode='lines',
                             name='Signal Line',
                             line=dict(color='red')
                            ),
                            row=3, col=1)

    # Create green bars for bullish, red for bearish
    hist_colors = ['green' if val >= 0 else 'red' for val in df_ohlc['macd_histogram']]
    
    # Add histogram bars to Row 3 (MACD)
    fig.add_trace(go.Bar(x=df_ohlc['timestamp'],
                         y=df_ohlc['macd_histogram'],
                         marker_color=hist_colors,
                         name='MACD Histogram',
                         opacity=0.5
                        ),
                        row=3, col=1)

    # Layout settings
    fig.update_layout(
        title={
            'text': f'Candlestick, RSI and MACD chart for {coin_id} over {days} days',
            'x': 0.5,
            'xanchor': 'center'
        },
        xaxis3_title = 'Date',
        yaxis_title = f"Price [{target_curr}]",
        yaxis2_title = 'RSI',
        yaxis3_title = 'MACD',
        height = 1000,
        template = "plotly"
    )   

    fig.show()

    return None

# %%
plot_candlestick_rsi_macd("bitcoin", "usd", 180, "2")

# %% [markdown]
# #### Bullish engulfing

# %%
def add_bullish_engulfing(df):

    df['bullish_engulfing'] = (
        (df['close'].shift(1) < df['open'].shift(1)) &  # previous red candle
        (df['close'] > df['open']) &                    # current green candle
        (df['close'] >= df['open'].shift(1)) &          # current close >= previous open
        (df['open'] <= df['close'].shift(1))            # current open <= previous close
    )

    return df

# %% [markdown]
# #### Plot candlestick + Bullish engulfing

# %%
def plot_candlestick_bullish_engulf(coin_id,
                                    target_curr,
                                    days,
                                    precision
                                   ):

    df_ohlc = get_ohlc_data(coin_id, 
                            target_curr,
                            days,
                            precision)
    
    df_ohlc = add_bullish_engulfing(df_ohlc)
    engulfing_df = df_ohlc[df_ohlc['bullish_engulfing']]

    target_curr = target_curr.upper()   

    fig = go.Figure()
    
    # Candlestick trace
    fig.add_trace(go.Candlestick(
        x = df_ohlc['timestamp'],
        open = df_ohlc['open'],
        high = df_ohlc['high'],
        low = df_ohlc['low'],
        close = df_ohlc['close'],
        name = 'OHLC'
    ))

    fig.add_trace(go.Scatter(
                            x=engulfing_df['timestamp'],
                            y=engulfing_df['low'] * 0.995,  # place marker just below the low
                            mode='markers',
                            marker=dict(
                                symbol='triangle-up',
                                size=14,
                                color='purple'
                            ),
                            name='Bullish Engulfing'
                            )
                 )

    # Update layout
    fig.update_layout(
        title=dict(
            text = f"Candlestick chart with Bullish Engulfing",
            x = 0.5,  # Center title
            xanchor = 'center'
        ),
        xaxis_title = 'Date',
        yaxis_title = f'Price [{target_curr}]',
        xaxis_rangeslider_visible = False,
        template = "plotly",
        height = 600
    )

    fig.show()

    return None

# %%
plot_candlestick_bullish_engulf("bitcoin", "usd", 180, "2")
